# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pyautogui
import time

plataforma = input('Plataforma: digite i para instagram e y para youtube:  ').upper()

if plataforma == 'Y':

    link = input('Entre com o link do vídeo que você quer baixar, em caso de falha, tente outro link de outro vídeo: ')

    driver = webdriver.Chrome()
    driver.get("https://pt.savefrom.net/31/")

    btn_more = driver.find_element(By.ID, 'sf_url').send_keys(link)
    pyautogui.press('enter')
    time.sleep(5)
    #driver.find_element_by_css_selector('#main > div.downloader-block > div.ssyoutube-helper-promo-h10.ssyoutube-helper-promo-h10-top > div.content__box > div.content_box__text_1 > p:nth-child(2) > a').click()
    print('Encontrei seu vídeo!')
    selecao = input('Achei seu vídeo! Digite a letra y para que eu possa baixar: ').upper()

    if selecao:

        driver.find_element_by_css_selector('#sf_result > div > div.result-box.video > div.info-box > div.link-box > div.def-btn-box > a').click()

    print('Seu vídeo está sendo baixado, confira sua pasta de Dowloads.')
    
    
    
    
if plataforma == 'I':
    
    link = input('Entre com o link do vídeo que você quer baixar, lembre-se que seu vídeo não pode ser de uma conta privada!: ')

    driver = webdriver.Chrome()
    driver.get("https://pt.savefrom.net/16/download-from-instagram")
    print('procurando...')
    btn_more = driver.find_element(By.ID, 'sf_url').send_keys(link)
    pyautogui.press('enter')
    time.sleep(5)
    print('Carregando...')
    
    selecao = input('Achei seu vídeo! Digite a letra I para que eu possa baixar: ').upper()

    if selecao:

        driver.find_element_by_css_selector('#sf_result > div > div.result-box.video > div.info-box > div.link-box.single > div.def-btn-box > a').click()

    print('Seu vídeo está sendo baixado, confira sua pasta de Dowloads.')
    
    
print('=-=-=-=-=-=-Desenvolvido por @Orlandu=-=-=-=-=-=-=-=-')
encerramento = input('pressione enter para encerrar: ')
# Out:
# Plataforma, digite i para instagram e y para youtube:  y
# Entre com o link do vídeo que você quer baixar: https://www.youtube.com/watch?v=w0z-TOs9gvA&list=RDGMEMQ1dJ7wXfLlqCjwV0xfSNbA&index=40
# Encontrei seu vídeo!
# Achei seu vídeo! Digite a letra y para que eu possa baixar: y
# Seu vídeo está sendo baixado, confira sua pasta de Dowloads.
# =-=-=-=-=-=-Desenvolvido por @Orlandu=-=-=-=-=-=-=-=-
